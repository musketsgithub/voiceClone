# %% [markdown]
# # Structure Extraction
#
# Implementation lives in `voice_clone.structure`; this notebook is just a runnable demo.

# %%
from voice_clone.structure import extract_structure

sample_text = """
Most startups think product quality is the bottleneck.
Usually it isn't. Distribution is.

Founders obsess over building better features while ignoring
the fact that nobody will ever see the product in the first place.

The companies that win often aren't the ones with the best products.
They're the ones that discover scalable distribution channels before
they run out of money.
"""

structure = extract_structure(sample_text)
print(structure)
