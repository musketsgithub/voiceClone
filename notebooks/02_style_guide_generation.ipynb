# %% [markdown]
# # Style Guide Generation
#
# Implementation lives in `voice_clone.style_guide`; this notebook is just a runnable demo.

# %%
from voice_clone.style_guide import generate_style_guide

corpus_texts = [
    "Most startups think product quality is the bottleneck. Usually it isn't. Distribution is.",
    "The hard part is rarely having ideas. It is making the right idea unavoidable to the right people.",
]

style_guide = generate_style_guide(corpus_texts)
print(style_guide)
