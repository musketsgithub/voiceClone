# %% [markdown]
# # Draft Regeneration
#
# Implementation lives in `voice_clone.regeneration`; this notebook is just a runnable demo.

# %%
from voice_clone.regeneration import regenerate_draft

structure_summary = """
- open by challenging a common belief about startup success
- argue distribution matters more than product quality
- explain founders focus excessively on building
- describe why attention acquisition is harder than engineering
- conclude distribution determines survival
"""

style_guide = """
HIGH-LEVEL DISCOURSE BEHAVIOR:
- begins with direct declarative claims
- prefers contrarian framing
- escalates toward broader implications
- avoids emotional language
- uses analytical progression
"""

draft = regenerate_draft(structure_summary, style_guide)
print(draft)
